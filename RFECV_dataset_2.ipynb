# %%
import pandas as pd
# from sklearn.preprocessing import MinMaxScaler
data = pd.read_csv(r"xxx\RFE_selected_features_2.csv", index_col=0)
pd.DataFrame(data)
# Out:
#                                     henry_cons  f-chi-0-all  f-chi-2-all  \
# filename
# [Cd(L2)(1-4-NDC)]n_no_solvent     4.170000e-05      95.8551     292.7000
# [Cd2(L1)(1-4-NDC)2]n_no_solvent   0.000000e+00     170.8842     675.4348
# [Cd3(L)(H2O)4(OH)2]_no_solvent    0.000000e+00     248.6487    1341.2710
# [Cd3Yb3L3(OH)3(OAc)6]_no_solvent  1.100000e-02     635.7651    4803.1848
# [Dy(TCPB)(DMF)3]n_no_solvent      3.530000e-03     334.8931    2082.3888
# ...                                        ...          ...          ...
# Zn-NDC_no_solvent                 8.340000e-03     170.6170     672.9868
# ZODXEX_no_solvent.cif             6.800000e-02     200.2609    1014.9484
# Zr-fum_no_solvent                 1.000000e-02     467.3186    4181.3352
# ZZZRNQ02_no_solvent.cif           0.000000e+00     334.2764    1780.8540
# ZZZSDW03_no_solvent.cif           2.300000e-22     744.6660    5458.7248
#
#                                   f-chi-3-all  f-Z-0-all  f-Z-2-all  \
# filename
# ...

# %%
from pycaret.classification import *
s = setup(data, target = 'label_y', session_id = 123)#, use_gpu = True
# Out:
# <style type="text/css">
# #T_53368_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_53368">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53368_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_53368_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53368_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53368_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_53368_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_53368_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_53368_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_53368_row1_col1" class="data row1 col1" >label_y</td>
#     </tr>
#     <tr>
#       <th id="T_53368_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_f7195 th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
tuned_mmodel = tune_model(best, n_iter = 2500)
# Out:
# <style type="text/css">
# #T_79c9b_row10_col0, #T_79c9b_row10_col1, #T_79c9b_row10_col2, #T_79c9b_row10_col3, #T_79c9b_row10_col4, #T_79c9b_row10_col5, #T_79c9b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_79c9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79c9b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_79c9b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_79c9b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_79c9b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_79c9b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_79c9b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_79c9b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
print(tuned_mmodel)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight={},
#                      criterion='entropy', max_depth=10, max_features=1.0,
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.005, min_samples_leaf=3,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      monotonic_cst=None, n_estimators=40, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)

# %%
evaluate_model(tuned_mmodel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 evaluate_model(tuned_mmodel)
#
# NameError: name 'tuned_mmodel' is not defined

# %%
# plot_model(best, plot = 'auc')
plot_model(tuned_mmodel, plot = 'confusion_matrix')
